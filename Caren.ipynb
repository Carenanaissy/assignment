# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Caren Al Anaissy__
# PhD student

# %% [markdown]
# _I am interested in data science because I like to gain insights from data_

# %% [markdown]
# ### The following code prints Hello

# %%
print('Hello')
# Out:
# Hello

# %% [markdown]
# 1. First item
# 2. Second item
# 3. Third item
#
# | Syntax | Description |
# | ----------- | ----------- |
# | Header | Title |
# | Paragraph | Text |
#
# [link](https://www.google.com)
